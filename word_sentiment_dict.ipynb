# %%
import numpy as np 
import pandas as pd
import csv

# %%
f = pd.read_csv('word_sentiment.csv')
f
# Out:
#               word      category  score
# 0            aback  anticipation      0
# 1            aback       disgust      0
# 2            aback         anger      0
# 3            aback          fear      0
# 4            aback           joy      0
# 5            aback      negative      0
# 6            aback      positive      0
# 7            aback       sadness      0
# 8            aback      surprise      0
# 9            aback         trust      0
# 10          abacus         anger      0
# 11          abacus  anticipation      0
# 12          abacus       disgust      0
# 13          abacus          fear      0
# 14          abacus           joy      0
# 15          abacus      negative      0
# 16          abacus      positive      0
# 17          abacus       sadness      0
# 18          abacus      surprise      0
# 19          abacus         trust      1
# 20         abandon         anger      0
# 21         abandon  anticipation      0
# 22         abandon       disgust      0
# 23         abandon          fear      1
# 24         abandon           joy      0
# 25         abandon      negative      1
# 26         abandon      positive      0
# 27         abandon       sadness      1
# 28         abandon      surprise      0
# 29         abandon         trust      0
# ...            ...           ...    ...
# 141790  zoological         anger      0
# 141791  zoological  anticipation      0
# 141792  zoological       disgust      0
# 141793  zoological          fear      0
# 141794  zoological           joy      0
# 141795  zoological      negative      0
# 141796  zoological      positive      0
# 141797  zoological       sadness      0
# 141798  zoological      surprise      0
# 141799  zoological         trust      0
# 141800     zoology         anger      0
# 141801     zoology  anticipation      0
# 141802     zoology       disgust      0
# 141803     zoology          fear      0
# 141804     zoology           joy      0
# 141805     zoology      negative      0
# 141806     zoology      positive      0
# 141807     zoology       sadness      0
# 141808     zoology      surprise      0
# 141809     zoology         trust      0
# 141810        zoom         anger      0
# 141811        zoom  anticipation      0
# 141812        zoom       disgust      0
# 141813        zoom          fear      0
# 141814        zoom           joy      0
# 141815        zoom      negative      0
# 141816        zoom      positive      0
# 141817        zoom       sadness      0
# 141818        zoom      surprise      0
# 141819        zoom         trust      0
#
# [141820 rows x 3 columns]

# %%
print(f['word'][0])
print(len(f))
# Out:
# aback
# 141820

# %%
word2sentiment = {f['word'][i]:f['category'][i] for i in range(len(f)) if f['score'][i] == 1}

# %%
print(word2sentiment['abacus'])
# Out:
# trust

# %%
sentiments = []
for i in range(len(f)):
    if f['category'][i] not in sentiments:
        sentiments.append(f['category'][i])
print(sentiments)
# Out:
# ['anticipation', 'disgust', 'anger', 'fear', 'joy', 'negative', 'positive', 'sadness', 'surprise', 'trust']

# %%
sentiment2words = {sentiments[i]:[] for i in range(len(sentiments))}
print(sentiment2words)
# Out:
# {'anticipation': [], 'disgust': [], 'anger': [], 'fear': [], 'joy': [], 'negative': [], 'positive': [], 'sadness': [], 'surprise': [], 'trust': []}

# %%
for word, sentiment in word2sentiment.items():
    sentiment2words[sentiment].append(word)

# %%
sentiment2words['anger']
# Out:
# []
